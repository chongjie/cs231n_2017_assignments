# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000L, 3073L)
# Train labels shape:  (49000L,)
# Validation data shape:  (1000L, 3073L)
# Validation labels shape:  (1000L,)
# Test data shape:  (1000L, 3073L)
# Test labels shape:  (1000L,)
# dev data shape:  (500L, 3073L)
# dev labels shape:  (500L,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.314349
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.838510 analytic: 0.838510, relative error: 1.103191e-08
# numerical: -0.402732 analytic: -0.402732, relative error: 1.211009e-07
# numerical: 0.449729 analytic: 0.449729, relative error: 4.359482e-09
# numerical: 0.237777 analytic: 0.237777, relative error: 3.291265e-08
# numerical: 2.480220 analytic: 2.480220, relative error: 2.018395e-09
# numerical: -0.944255 analytic: -0.944255, relative error: 2.260762e-08
# numerical: -0.080081 analytic: -0.080081, relative error: 4.473044e-07
# numerical: 0.651669 analytic: 0.651669, relative error: 4.669372e-08
# numerical: 0.804979 analytic: 0.804979, relative error: 3.921212e-08
# numerical: -0.879111 analytic: -0.879111, relative error: 1.412075e-08
# numerical: 0.031316 analytic: 0.031316, relative error: 2.062918e-07
# numerical: -0.155380 analytic: -0.155380, relative error: 1.503513e-07
# numerical: -0.240283 analytic: -0.240283, relative error: 4.298423e-09
# numerical: -0.920246 analytic: -0.920246, relative error: 9.953498e-09
# numerical: -0.213614 analytic: -0.213614, relative error: 9.204473e-08
# numerical: -0.512588 analytic: -0.512588, relative error: 7.813098e-08
# numerical: -2.246901 analytic: -2.246901, relative error: 3.902744e-08
# numerical: -0.947134 analytic: -0.947134, relative error: 4.833261e-09
# numerical: 0.112280 analytic: 0.112280, relative error: 2.010180e-07
# numerical: -2.354071 analytic: -2.354071, relative error: 4.659116e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.314349e+00 computed in 0.091000s
# vectorized loss: 2.314349e+00 computed in 0.004000s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in np.linspace(learning_rates[0], learning_rates[1], num = 10):
    for reg in np.linspace(regularization_strengths[0], regularization_strengths[1], num = 10):
        print('Processing parameter lr %e and reg %e' %(lr, reg))
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=False)
        y_train_pred = softmax.predict(X_train)
        train_acc = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_acc = np.mean(y_val == y_val_pred)
        results[(lr,reg)] = [train_acc, val_acc]
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Processing parameter lr 1.000000e-07 and reg 2.500000e+04
# Processing parameter lr 1.000000e-07 and reg 2.777778e+04
# Processing parameter lr 1.000000e-07 and reg 3.055556e+04
# Processing parameter lr 1.000000e-07 and reg 3.333333e+04
# Processing parameter lr 1.000000e-07 and reg 3.611111e+04
# Processing parameter lr 1.000000e-07 and reg 3.888889e+04
# Processing parameter lr 1.000000e-07 and reg 4.166667e+04
# Processing parameter lr 1.000000e-07 and reg 4.444444e+04
# Processing parameter lr 1.000000e-07 and reg 4.722222e+04
# Processing parameter lr 1.000000e-07 and reg 5.000000e+04
# Processing parameter lr 1.444444e-07 and reg 2.500000e+04
# Processing parameter lr 1.444444e-07 and reg 2.777778e+04
# Processing parameter lr 1.444444e-07 and reg 3.055556e+04
# Processing parameter lr 1.444444e-07 and reg 3.333333e+04
# Processing parameter lr 1.444444e-07 and reg 3.611111e+04
# Processing parameter lr 1.444444e-07 and reg 3.888889e+04
# Processing parameter lr 1.444444e-07 and reg 4.166667e+04
# Processing parameter lr 1.444444e-07 and reg 4.444444e+04
# Processing parameter lr 1.444444e-07 and reg 4.722222e+04
# Processing parameter lr 1.444444e-07 and reg 5.000000e+04
# Processing parameter lr 1.888889e-07 and reg 2.500000e+04
# Processing parameter lr 1.888889e-07 and reg 2.777778e+04
# Processing parameter lr 1.888889e-07 and reg 3.055556e+04
# Processing parameter lr 1.888889e-07 and reg 3.333333e+04
# Processing parameter lr 1.888889e-07 and reg 3.611111e+04
# Processing parameter lr 1.888889e-07 and reg 3.888889e+04
# Processing parameter lr 1.888889e-07 and reg 4.166667e+04
# Processing parameter lr 1.888889e-07 and reg 4.444444e+04
# Processing parameter lr 1.888889e-07 and reg 4.722222e+04
# Processing parameter lr 1.888889e-07 and reg 5.000000e+04
# Processing parameter lr 2.333333e-07 and reg 2.500000e+04
# Processing parameter lr 2.333333e-07 and reg 2.777778e+04
# Processing parameter lr 2.333333e-07 and reg 3.055556e+04
# Processing parameter lr 2.333333e-07 and reg 3.333333e+04
# Processing parameter lr 2.333333e-07 and reg 3.611111e+04
# Processing parameter lr 2.333333e-07 and reg 3.888889e+04
# Processing parameter lr 2.333333e-07 and reg 4.166667e+04
# Processing parameter lr 2.333333e-07 and reg 4.444444e+04
# Processing parameter lr 2.333333e-07 and reg 4.722222e+04
# Processing parameter lr 2.333333e-07 and reg 5.000000e+04
# Processing parameter lr 2.777778e-07 and reg 2.500000e+04
# Processing parameter lr 2.777778e-07 and reg 2.777778e+04
# Processing parameter lr 2.777778e-07 and reg 3.055556e+04
# Processing parameter lr 2.777778e-07 and reg 3.333333e+04
# Processing parameter lr 2.777778e-07 and reg 3.611111e+04
# Processing parameter lr 2.777778e-07 and reg 3.888889e+04
# Processing parameter lr 2.777778e-07 and reg 4.166667e+04
# Processing parameter lr 2.777778e-07 and reg 4.444444e+04
# Processing parameter lr 2.777778e-07 and reg 4.722222e+04
# Processing parameter lr 2.777778e-07 and reg 5.000000e+04
# Processing parameter lr 3.222222e-07 and reg 2.500000e+04
# Processing parameter lr 3.222222e-07 and reg 2.777778e+04
# Processing parameter lr 3.222222e-07 and reg 3.055556e+04
# Processing parameter lr 3.222222e-07 and reg 3.333333e+04
# Processing parameter lr 3.222222e-07 and reg 3.611111e+04
# Processing parameter lr 3.222222e-07 and reg 3.888889e+04
# Processing parameter lr 3.222222e-07 and reg 4.166667e+04
# Processing parameter lr 3.222222e-07 and reg 4.444444e+04
# Processing parameter lr 3.222222e-07 and reg 4.722222e+04
# Processing parameter lr 3.222222e-07 and reg 5.000000e+04
# Processing parameter lr 3.666667e-07 and reg 2.500000e+04
# Processing parameter lr 3.666667e-07 and reg 2.777778e+04
# Processing parameter lr 3.666667e-07 and reg 3.055556e+04
# Processing parameter lr 3.666667e-07 and reg 3.333333e+04
# Processing parameter lr 3.666667e-07 and reg 3.611111e+04
# Processing parameter lr 3.666667e-07 and reg 3.888889e+04
# Processing parameter lr 3.666667e-07 and reg 4.166667e+04
# Processing parameter lr 3.666667e-07 and reg 4.444444e+04
# Processing parameter lr 3.666667e-07 and reg 4.722222e+04
# Processing parameter lr 3.666667e-07 and reg 5.000000e+04
# Processing parameter lr 4.111111e-07 and reg 2.500000e+04
# Processing parameter lr 4.111111e-07 and reg 2.777778e+04
# Processing parameter lr 4.111111e-07 and reg 3.055556e+04
# Processing parameter lr 4.111111e-07 and reg 3.333333e+04
# Processing parameter lr 4.111111e-07 and reg 3.611111e+04
# Processing parameter lr 4.111111e-07 and reg 3.888889e+04
# Processing parameter lr 4.111111e-07 and reg 4.166667e+04
# Processing parameter lr 4.111111e-07 and reg 4.444444e+04
# Processing parameter lr 4.111111e-07 and reg 4.722222e+04
# Processing parameter lr 4.111111e-07 and reg 5.000000e+04
# Processing parameter lr 4.555556e-07 and reg 2.500000e+04
# Processing parameter lr 4.555556e-07 and reg 2.777778e+04
# Processing parameter lr 4.555556e-07 and reg 3.055556e+04
# Processing parameter lr 4.555556e-07 and reg 3.333333e+04
# Processing parameter lr 4.555556e-07 and reg 3.611111e+04
# Processing parameter lr 4.555556e-07 and reg 3.888889e+04
# Processing parameter lr 4.555556e-07 and reg 4.166667e+04
# Processing parameter lr 4.555556e-07 and reg 4.444444e+04
# Processing parameter lr 4.555556e-07 and reg 4.722222e+04
# Processing parameter lr 4.555556e-07 and reg 5.000000e+04
# Processing parameter lr 5.000000e-07 and reg 2.500000e+04
# Processing parameter lr 5.000000e-07 and reg 2.777778e+04
# Processing parameter lr 5.000000e-07 and reg 3.055556e+04
# Processing parameter lr 5.000000e-07 and reg 3.333333e+04
# Processing parameter lr 5.000000e-07 and reg 3.611111e+04
# Processing parameter lr 5.000000e-07 and reg 3.888889e+04
# Processing parameter lr 5.000000e-07 and reg 4.166667e+04
# Processing parameter lr 5.000000e-07 and reg 4.444444e+04
# Processing parameter lr 5.000000e-07 and reg 4.722222e+04
# Processing parameter lr 5.000000e-07 and reg 5.000000e+04
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.348184 val accuracy: 0.362000
# lr 1.000000e-07 reg 2.777778e+04 train accuracy: 0.348918 val accuracy: 0.363000
# lr 1.000000e-07 reg 3.055556e+04 train accuracy: 0.342796 val accuracy: 0.359000
# lr 1.000000e-07 reg 3.333333e+04 train accuracy: 0.345224 val accuracy: 0.358000
# lr 1.000000e-07 reg 3.611111e+04 train accuracy: 0.338653 val accuracy: 0.348000
# lr 1.000000e-07 reg 3.888889e+04 train accuracy: 0.339490 val accuracy: 0.356000
# lr 1.000000e-07 reg 4.166667e+04 train accuracy: 0.332041 val accuracy: 0.349000
# lr 1.000000e-07 reg 4.444444e+04 train accuracy: 0.331980 val accuracy: 0.345000
# lr 1.000000e-07 reg 4.722222e+04 train accuracy: 0.334163 val accuracy: 0.345000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.329327 val accuracy: 0.348000
# lr 1.444444e-07 reg 2.500000e+04 train accuracy: 0.344837 val accuracy: 0.362000
# lr 1.444444e-07 reg 2.777778e+04 train accuracy: 0.349592 val accuracy: 0.360000
# lr 1.444444e-07 reg 3.055556e+04 train accuracy: 0.347592 val accuracy: 0.358000
# lr 1.444444e-07 reg 3.333333e+04 train accuracy: 0.342347 val accuracy: 0.358000
# lr 1.444444e-07 reg 3.611111e+04 train accuracy: 0.338490 val accuracy: 0.345000
# lr 1.444444e-07 reg 3.888889e+04 train accuracy: 0.334714 val accuracy: 0.350000
# lr 1.444444e-07 reg 4.166667e+04 train accuracy: 0.338367 val accuracy: 0.356000
# lr 1.444444e-07 reg 4.444444e+04 train accuracy: 0.333469 val accuracy: 0.347000
# lr 1.444444e-07 reg 4.722222e+04 train accuracy: 0.325612 val accuracy: 0.341000
# lr 1.444444e-07 reg 5.000000e+04 train accuracy: 0.334796 val accuracy: 0.352000
# lr 1.888889e-07 reg 2.500000e+04 train accuracy: 0.353367 val accuracy: 0.367000
# lr 1.888889e-07 reg 2.777778e+04 train accuracy: 0.349163 val accuracy: 0.369000
# lr 1.888889e-07 reg 3.055556e+04 train accuracy: 0.342367 val accuracy: 0.351000
# lr 1.888889e-07 reg 3.333333e+04 train accuracy: 0.340041 val accuracy: 0.358000
# lr 1.888889e-07 reg 3.611111e+04 train accuracy: 0.338898 val accuracy: 0.360000
# lr 1.888889e-07 reg 3.888889e+04 train accuracy: 0.337224 val accuracy: 0.356000
# lr 1.888889e-07 reg 4.166667e+04 train accuracy: 0.330510 val accuracy: 0.347000
# lr 1.888889e-07 reg 4.444444e+04 train accuracy: 0.335163 val accuracy: 0.358000
# lr 1.888889e-07 reg 4.722222e+04 train accuracy: 0.328837 val accuracy: 0.351000
# lr 1.888889e-07 reg 5.000000e+04 train accuracy: 0.328163 val accuracy: 0.344000
# lr 2.333333e-07 reg 2.500000e+04 train accuracy: 0.348694 val accuracy: 0.370000
# lr 2.333333e-07 reg 2.777778e+04 train accuracy: 0.345694 val accuracy: 0.363000
# lr 2.333333e-07 reg 3.055556e+04 train accuracy: 0.341041 val accuracy: 0.359000
# lr 2.333333e-07 reg 3.333333e+04 train accuracy: 0.343163 val accuracy: 0.355000
# lr 2.333333e-07 reg 3.611111e+04 train accuracy: 0.333122 val accuracy: 0.346000
# lr 2.333333e-07 reg 3.888889e+04 train accuracy: 0.339612 val accuracy: 0.356000
# lr 2.333333e-07 reg 4.166667e+04 train accuracy: 0.330959 val accuracy: 0.349000
# lr 2.333333e-07 reg 4.444444e+04 train accuracy: 0.340531 val accuracy: 0.354000
# lr 2.333333e-07 reg 4.722222e+04 train accuracy: 0.331796 val accuracy: 0.337000
# lr 2.333333e-07 reg 5.000000e+04 train accuracy: 0.332000 val accuracy: 0.343000
# lr 2.777778e-07 reg 2.500000e+04 train accuracy: 0.346980 val accuracy: 0.364000
# lr 2.777778e-07 reg 2.777778e+04 train accuracy: 0.347306 val accuracy: 0.363000
# lr 2.777778e-07 reg 3.055556e+04 train accuracy: 0.337857 val accuracy: 0.354000
# lr 2.777778e-07 reg 3.333333e+04 train accuracy: 0.336306 val accuracy: 0.355000
# lr 2.777778e-07 reg 3.611111e+04 train accuracy: 0.341204 val accuracy: 0.351000
# lr 2.777778e-07 reg 3.888889e+04 train accuracy: 0.342490 val accuracy: 0.364000
# lr 2.777778e-07 reg 4.166667e+04 train accuracy: 0.336020 val accuracy: 0.342000
# lr 2.777778e-07 reg 4.444444e+04 train accuracy: 0.325735 val accuracy: 0.343000
# lr 2.777778e-07 reg 4.722222e+04 train accuracy: 0.327102 val accuracy: 0.347000
# lr 2.777778e-07 reg 5.000000e+04 train accuracy: 0.323694 val accuracy: 0.340000
# lr 3.222222e-07 reg 2.500000e+04 train accuracy: 0.345796 val accuracy: 0.359000
# lr 3.222222e-07 reg 2.777778e+04 train accuracy: 0.344020 val accuracy: 0.360000
# lr 3.222222e-07 reg 3.055556e+04 train accuracy: 0.347980 val accuracy: 0.367000
# lr 3.222222e-07 reg 3.333333e+04 train accuracy: 0.344857 val accuracy: 0.355000
# lr 3.222222e-07 reg 3.611111e+04 train accuracy: 0.330224 val accuracy: 0.352000
# lr 3.222222e-07 reg 3.888889e+04 train accuracy: 0.330061 val accuracy: 0.340000
# lr 3.222222e-07 reg 4.166667e+04 train accuracy: 0.336367 val accuracy: 0.353000
# lr 3.222222e-07 reg 4.444444e+04 train accuracy: 0.327612 val accuracy: 0.345000
# lr 3.222222e-07 reg 4.722222e+04 train accuracy: 0.330102 val accuracy: 0.333000
# lr 3.222222e-07 reg 5.000000e+04 train accuracy: 0.328061 val accuracy: 0.334000
# lr 3.666667e-07 reg 2.500000e+04 train accuracy: 0.342265 val accuracy: 0.357000
# lr 3.666667e-07 reg 2.777778e+04 train accuracy: 0.344490 val accuracy: 0.350000
# lr 3.666667e-07 reg 3.055556e+04 train accuracy: 0.335796 val accuracy: 0.351000
# lr 3.666667e-07 reg 3.333333e+04 train accuracy: 0.340082 val accuracy: 0.356000
# lr 3.666667e-07 reg 3.611111e+04 train accuracy: 0.341551 val accuracy: 0.364000
# lr 3.666667e-07 reg 3.888889e+04 train accuracy: 0.342020 val accuracy: 0.354000
# lr 3.666667e-07 reg 4.166667e+04 train accuracy: 0.333612 val accuracy: 0.338000
# lr 3.666667e-07 reg 4.444444e+04 train accuracy: 0.327939 val accuracy: 0.335000
# lr 3.666667e-07 reg 4.722222e+04 train accuracy: 0.334673 val accuracy: 0.350000
# lr 3.666667e-07 reg 5.000000e+04 train accuracy: 0.329694 val accuracy: 0.352000
# lr 4.111111e-07 reg 2.500000e+04 train accuracy: 0.348102 val accuracy: 0.356000
# lr 4.111111e-07 reg 2.777778e+04 train accuracy: 0.344061 val accuracy: 0.358000
# lr 4.111111e-07 reg 3.055556e+04 train accuracy: 0.346102 val accuracy: 0.358000
# lr 4.111111e-07 reg 3.333333e+04 train accuracy: 0.343796 val accuracy: 0.353000
# lr 4.111111e-07 reg 3.611111e+04 train accuracy: 0.336388 val accuracy: 0.361000
# lr 4.111111e-07 reg 3.888889e+04 train accuracy: 0.326592 val accuracy: 0.342000
# lr 4.111111e-07 reg 4.166667e+04 train accuracy: 0.333041 val accuracy: 0.340000
# lr 4.111111e-07 reg 4.444444e+04 train accuracy: 0.323837 val accuracy: 0.344000
# lr 4.111111e-07 reg 4.722222e+04 train accuracy: 0.325041 val accuracy: 0.336000
# lr 4.111111e-07 reg 5.000000e+04 train accuracy: 0.324367 val accuracy: 0.340000
# lr 4.555556e-07 reg 2.500000e+04 train accuracy: 0.347653 val accuracy: 0.367000
# lr 4.555556e-07 reg 2.777778e+04 train accuracy: 0.346224 val accuracy: 0.364000
# lr 4.555556e-07 reg 3.055556e+04 train accuracy: 0.339163 val accuracy: 0.358000
# lr 4.555556e-07 reg 3.333333e+04 train accuracy: 0.334857 val accuracy: 0.342000
# lr 4.555556e-07 reg 3.611111e+04 train accuracy: 0.329735 val accuracy: 0.348000
# lr 4.555556e-07 reg 3.888889e+04 train accuracy: 0.340327 val accuracy: 0.356000
# lr 4.555556e-07 reg 4.166667e+04 train accuracy: 0.323959 val accuracy: 0.337000
# lr 4.555556e-07 reg 4.444444e+04 train accuracy: 0.327102 val accuracy: 0.335000
# lr 4.555556e-07 reg 4.722222e+04 train accuracy: 0.329429 val accuracy: 0.345000
# lr 4.555556e-07 reg 5.000000e+04 train accuracy: 0.319837 val accuracy: 0.338000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.339367 val accuracy: 0.359000
# lr 5.000000e-07 reg 2.777778e+04 train accuracy: 0.339000 val accuracy: 0.348000
# lr 5.000000e-07 reg 3.055556e+04 train accuracy: 0.337122 val accuracy: 0.355000
# lr 5.000000e-07 reg 3.333333e+04 train accuracy: 0.333306 val accuracy: 0.356000
# lr 5.000000e-07 reg 3.611111e+04 train accuracy: 0.333367 val accuracy: 0.355000
# lr 5.000000e-07 reg 3.888889e+04 train accuracy: 0.336857 val accuracy: 0.353000
# lr 5.000000e-07 reg 4.166667e+04 train accuracy: 0.333796 val accuracy: 0.351000
# lr 5.000000e-07 reg 4.444444e+04 train accuracy: 0.335469 val accuracy: 0.350000
# lr 5.000000e-07 reg 4.722222e+04 train accuracy: 0.336265 val accuracy: 0.344000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.328408 val accuracy: 0.336000
# best validation accuracy achieved during cross-validation: 0.370000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.355000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
